# %%
import pandas as pd
import statsmodels.api as sm
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
import numpy as np
import time
from tqdm import tqdm
from lightgbm import LGBMClassifier

# %% [markdown]
# ### 6개월치 proba 평균

# %%
df_weather=pd.read_csv('static/data/기상데이터 0510 index X.csv')
df_weather.head()
# Out:
#          관측일자  temperature  temp_max  temp_min  rainfall  humidity 조사지역     연  \
# 0  1988-01-01         -2.4      -0.8      -4.4       0.5      64.0   서울  1988
# 1  1988-01-01         -2.6       0.5      -6.2       1.9      73.0  관악산  1988
# 2  1988-01-01         -4.1      -0.7      -8.6       0.0      66.0   춘천  1988
# 3  1988-01-01         -3.1      -1.0      -8.6       0.4      79.0   철원  1988
# 4  1988-01-01          3.7       6.5       0.1       0.0      57.0   속초  1988
#
#    월  일
# 0  1  1
# 1  1  1
# 2  1  1
# 3  1  1
# 4  1  1

# %%
df_grain=pd.read_csv('static/data/0515_작물추가.csv')
df_grain.head()
# Out:
#    temperature    rainfall  temp_min  temp_max label
# 0    20.879744  202.935536        18        28  rice
# 1    21.770462  226.655537        18        28  rice
# 2    23.004459  263.964248        18        28  rice
# 3    26.491096  242.864034        18        28  rice
# 4    20.130175  262.717340        18        28  rice

# %%
df_grain['label'].value_counts()
# Out:
# wheat          101
# cocoa          101
# rice           100
# 고추             100
# 감              100
# 레빗아이 블루베리      100
# 하이부시 블루베리      100
# 딸기             100
# 토마토            100
# 가지             100
# 오이             100
# 베              100
# 참외             100
# 멜론             100
# 호박             100
# 마늘             100
# 시금치            100
# 무              100
# 배추             100
# 상추             100
# 살구             100
# 복숭아            100
# maize          100
# 매실             100
# chickpea       100
# kidneybeans    100
# lentil         100
# pomegranate    100
# banana         100
# mango          100
# grapes         100
# watermelon     100
# muskmelon      100
# apple          100
# orange         100
# papaya         100
# coconut        100
# cotton         100
# coffee         100
# 양파             100
# Name: label, dtype: int64

# %%
# 6개월치 데이터를 추합 return 습도 x
def predict_6m_proba(region, start_month, pred_year):
    df = pd.DataFrame()
    for mon in range(start_month, start_month+6):
        pred_data = OLS_model_predict(region, mon, pred_year)
        # print(pred_data)
        tmp_data =[]
        for data in pred_data :
            tmp_data.append(data[-1])
        # print(tmp_data)
        df_pred  = predict_crops_6m(tmp_data)
        df = pd.concat([df, df_pred])
    return df.groupby(df.index).mean().sort_values(by='확률', ascending=False)

def predict_crops_6m(data):
    tmp_grain = df_grain[['temperature', 'temp_max', 'temp_min',  'rainfall', 'label']]
    xgb = XGBClassifier(booster = 'gbtree', learning_rate = 0.01, n_estimators = 10)  
    labelencoder = LabelEncoder()
    target_lb = labelencoder.fit_transform(tmp_grain.label)
    scaler = MinMaxScaler()
    grain_data = tmp_grain[tmp_grain.columns[:-1]]

    grain_data= grain_data.append({'temperature' :  data[0], 'temp_max' : data[1], 'temp_min' : data[2], 'rainfall' : data[3]*30} , ignore_index=True)

    grain_mmx = scaler.fit_transform(grain_data)



    X_train, X_test, y_train, y_test = train_test_split(
        grain_mmx[:-1], target_lb, stratify=target_lb, test_size=0.2,
        random_state=2022
    )
    xgb.fit(X_train, y_train)

    print(grain_mmx[-1])
    print(labelencoder.classes_)
    df_pred = pd.DataFrame(xgb.predict_proba((grain_mmx[-1].reshape(1,-1))), columns=labelencoder.classes_).T
    df_pred.columns = ['확률']
    df_pred = df_pred.sort_values(by='확률',ascending=False)
    return_pred = df_pred
    return return_pred

def OLS_model_predict(region, month, pred_year):
    df_tmp_region = df_weather[df_weather['조사지역'] == region]
    df_weather_region = df_tmp_region.groupby(['조사지역', '관측일자']).mean()
    df_weather_region = df_weather_region.reset_index(drop=False)

    df_group_mean = df_weather_region.groupby(['연', '월']).mean()
    df_group_mean = df_group_mean.reset_index(drop=False)
    df_month_mean = df_group_mean[df_group_mean['월'] == month]

    for i in df_month_mean.index:
        df_tmp = df_weather_region.loc[(df_weather_region['연'] == df_month_mean.loc[i, '연']) & (df_weather_region['월'] == df_month_mean.loc[i, '월'])]
        temp_max = df_tmp['temp_max'].max()
        temp_min = df_tmp['temp_min'].min()
        df_month_mean.loc[i, 'temp_max'] = temp_max
        df_month_mean.loc[i, 'temp_min'] = temp_min


    pred_list = []
    for value in df_month_mean.columns[2: -1]:
        df_target = df_month_mean[value]
        X_train2 = pd.DataFrame(df_month_mean[['연']], columns = ['연'])
        y_train2 = df_target.values

        # import statsmodels.api as sm
        X_train = sm.add_constant(X_train2)
        model = sm.OLS(y_train2, X_train2).fit()
        pred_value = model.predict(pred_year)
        pred_list.append([value, float(pred_value)])

    # print(f'\t\t\t{region}의 {month}월 {pred_year}의 예측값:')
    # print(pred_list)
    return pred_list

# %%
predict_6m_proba('서울', 3, 2022)
# Out:
# [13:41:01] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0.         0.14845221 0.39091017 0.02928312]
# ['apple' 'banana' 'chickpea' 'cocoa' 'coconut' 'coffee' 'cotton' 'grapes'
#  'kidneybeans' 'lentil' 'maize' 'mango' 'muskmelon' 'orange' 'papaya'
#  'pomegranate' 'rice' 'watermelon' 'wheat' '가지' '감' '고추' '딸기' '레빗아이 블루베리'
#  '마늘' '매실' '멜론' '무' '배추' '베' '복숭아' '살구' '상추' '시금치' '양파' '오이' '참외' '토마토'
#  '하이부시 블루베리' '호박']
# [13:41:06] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0.11298909 0.45742011 0.52368955 0.04863353]
# ['apple' 'banana' 'chickpea' 'cocoa' 'coconut' 'coffee' 'cotton' 'grapes'
#  'kidneybeans' 'lentil' 'maize' 'mango' 'muskmelon' 'orange' 'papaya'
#  'pomegranate' 'rice' 'watermelon' 'wheat' '가지' '감' '고추' '딸기' '레빗아이 블루베리'
#  '마늘' '매실' '멜론' '무' '배추' '베' '복숭아' '살구' '상추' '시금치' '양파' '오이' '참외' '토마토'
#  '하이부시 블루베리' '호박']
# [13:41:11] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0.26782186 0.642786   0.64693917 0.06576816]
# ['apple' 'banana' 'chickpea' 'cocoa' 'coconut' 'coffee' 'cotton' 'grapes'
#  'kidneybeans' 'lentil' 'maize' 'mango' 'muskmelon' 'orange' 'papaya'
#  'pomegranate' 'rice' 'watermelon' 'wheat' '가지' '감' '고추' '딸기' '레빗아이 블루베리'
#  '마늘' '매실' '멜론' '무' '배추' '베' '복숭아' '살구' '상추' '시금치' '양파' '오이' '참외' '토마토'
#  '하이부시 블루베리' '호박']
# [13:41:16] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0.4010625  0.75731893 0.75982506 0.094782  ]
# ['apple' 'banana' 'chickpea' 'cocoa' 'coconut' 'coffee' 'cotton' 'grapes'
#  'kidneybeans' 'lentil' 'maize' 'mango' 'muskmelon' 'orange' 'papaya'
#  'pomegranate' 'rice' 'watermelon' 'wheat' '가지' '감' '고추' '딸기' '레빗아이 블루베리'
#  '마늘' '매실' '멜론' '무' '배추' '베' '복숭아' '살구' '상추' '시금치' '양파' '오이' '참외' '토마토'
#  '하이부시 블루베리' '호박']
# [13:41:21] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0.4796662  0.82028935 0.84520883 0.26672323]
# ['apple' 'banana' 'chickpea' 'cocoa' 'coconut' 'coffee' 'cotton' 'grapes'
#  'kidneybeans' 'lentil' 'maize' 'mango' 'muskmelon' 'orange' 'papaya'
#  'pomegranate' 'rice' 'watermelon' 'wheat' '가지' '감' '고추' '딸기' '레빗아이 블루베리'
#  '마늘' '매실' '멜론' '무' '배추' '베' '복숭아' '살구' '상추' '시금치' '양파' '오이' '참외' '토마토'
#  '하이부시 블루베리' '호박']
# [13:41:26] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0.50109824 0.8667877  0.82568668 0.2197812 ]
# ['apple' 'banana' 'chickpea' 'cocoa' 'coconut' 'coffee' 'cotton' 'grapes'
#  'kidneybeans' 'lentil' 'maize' 'mango' 'muskmelon' 'orange' 'papaya'
#  'pomegranate' 'rice' 'watermelon' 'wheat' '가지' '감' '고추' '딸기' '레빗아이 블루베리'
#  '마늘' '매실' '멜론' '무' '배추' '베' '복숭아' '살구' '상추' '시금치' '양파' '오이' '참외' '토마토'
#  '하이부시 블루베리' '호박']
#                    확률
# 멜론           0.031920
# kidneybeans  0.031215
# 딸기           0.031196
# 매실           0.030872
# grapes       0.030869
# lentil       0.030866
# maize        0.029268
# rice         0.023830
# cocoa        0.023822
# chickpea     0.023801
# 배추           0.023774
# 상추           0.023771
# coffee       0.023755
# 고추           0.023753
# watermelon   0.023752
# 호박           0.023751
# 오이           0.023750
# 참외           0.023750
# 시금치          0.023748
# 무            0.023748
# wheat        0.023747
# 마늘           0.023746
# 가지           0.023746
# 양파           0.023745
# 토마토          0.023745
# apple        0.023744
# banana       0.023738
# cotton       0.023738
# coconut      0.023738
# 레빗아이 블루베리    0.023737
# papaya       0.023737
# 복숭아          0.023737
# 감            0.023737
# 살구           0.023737
# pomegranate  0.023736
# 베            0.023736
# mango        0.023736
# muskmelon    0.023736
# 하이부시 블루베리    0.023736
# orange       0.023736

# %%
df.groupby(df.index).mean().sort_values(by='확률', ascending=False).head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6개월 지역 작물 예측 모델.ipynb Cell 8' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000007?line=0'>1</a> df.groupby(df.index).mean().sort_values(by='확률', ascending=False).head(3)
#
# NameError: name 'df' is not defined

# %%
for region in tqdm(df_weather['조사지역'].unique()) :
    print(f'{region}지역 추천 Top 3 작물')
    display(predict_6m_proba(region, 3, 2022).head(3))
    print('\n')
# Out:
#   0%|          | 0/73 [00:00<?, ?it/s]
# 서울지역 추천 Top 3 작물
#   0%|          | 0/73 [00:03<?, ?it/s]
# [12:38:42] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6개월 지역 작물 예측 모델.ipynb Cell 9' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000008?line=0'>1</a> for region in tqdm(df_weather['조사지역'].unique()) :
#       <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000008?line=1'>2</a>     print(f'{region}지역 추천 Top 3 작물')
# ----> <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000008?line=2'>3</a>     display(predict_6m_proba(region, 3, 2022).head(3))
#       <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000008?line=3'>4</a>     print('\n')
#
# /Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6개월 지역 작물 예측 모델.ipynb Cell 6' in predict_6m_proba(region, start_month, pred_year)
#       <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000005?line=8'>9</a>         tmp_data.append(data[-1])
#      <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000005?line=9'>10</a>     # print(tmp_data)
# ---> <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000005?line=10'>11</a>     df_pred  = predict_crops_6m(tmp_data)
#      <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000005?line=11'>12</a>     df = pd.concat([df, df_pred])
#      <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000005?line=12'>13</a> return df.groupby(df.index).mean().sort_values(by='확률', ascending=False)
#
# /Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6개월 지역 작물 예측 모델.ipynb Cell 6' in predict_crops_6m(data)
#      <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000005?line=34'>35</a> xgb.fit(X_train, y_train)
#      <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000005?line=36'>37</a> # print(grain_mmx[-1])
# ---> <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000005?line=37'>38</a> df_pred = pd.DataFrame(xgb.predict_proba(list(grain_mmx[-1])), columns=labelencoder.classes_).T
#      <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000005?line=38'>39</a> df_pred.columns = ['확률']
#      <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000005?line=39'>40</a> df_pred = df_pred.sort_values(by='확률',ascending=False)
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py:1348, in XGBClassifier.predict_proba(self, X, ntree_limit, validate_features, base_margin, iteration_range)
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=1315'>1316</a> """ Predict the probability of each `X` example being of a given class.
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=1316'>1317</a>
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=1317'>1318</a> .. note:: This function is only thread safe for `gbtree` and `dart`.
#    (...)
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=1340'>1341</a>     probability of each data example being of a given class.
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=1341'>1342</a> """
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=1342'>1343</a> # custom obj:      Do nothing as we don't know what to do.
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=1343'>1344</a> # softprob:        Do nothing, output is proba.
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=1344'>1345</a> # softmax:         Use output margin to remove the argmax in PredTransform.
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=1345'>1346</a> # binary:logistic: Expand the prob vector into 2-class matrix after predict.
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=1346'>1347</a> # binary:logitraw: Unsupported by predict_proba()
# -> <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=1347'>1348</a> class_probs = super().predict(
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=1348'>1349</a>     X=X,
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=1349'>1350</a>     output_margin=self.objective == "multi:softmax",
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=1350'>1351</a>     ntree_limit=ntree_limit,
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=1351'>1352</a>     validate_features=validate_features,
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=1352'>1353</a>     base_margin=base_margin,
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=1353'>1354</a>     iteration_range=iteration_range
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=1354'>1355</a> )
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=1355'>1356</a> # If model is loaded from a raw booster there's no `n_classes_`
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=1356'>1357</a> return _cls_predict_proba(
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=1357'>1358</a>     getattr(self, "n_classes_", None), class_probs, np.vstack
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=1358'>1359</a> )
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py:897, in XGBModel.predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=892'>893</a>     except TypeError:
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=893'>894</a>         # coo, csc, dt
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=894'>895</a>         pass
# --> <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=896'>897</a> test = DMatrix(
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=897'>898</a>     X, base_margin=base_margin,
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=898'>899</a>     missing=self.missing,
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=899'>900</a>     nthread=self.n_jobs,
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=900'>901</a>     enable_categorical=self.enable_categorical
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=901'>902</a> )
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=902'>903</a> return self.get_booster().predict(
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=903'>904</a>     data=test,
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=904'>905</a>     iteration_range=iteration_range,
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=905'>906</a>     output_margin=output_margin,
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=906'>907</a>     validate_features=validate_features,
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/sklearn.py?line=907'>908</a> )
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/core.py:506, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/core.py?line=503'>504</a> for k, arg in zip(sig.parameters, args):
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/core.py?line=504'>505</a>     kwargs[k] = arg
# --> <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/core.py?line=505'>506</a> return f(**kwargs)
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/core.py:616, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/core.py?line=612'>613</a>     assert self.handle is not None
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/core.py?line=613'>614</a>     return
# --> <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/core.py?line=615'>616</a> handle, feature_names, feature_types = dispatch_data_backend(
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/core.py?line=616'>617</a>     data,
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/core.py?line=617'>618</a>     missing=self.missing,
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/core.py?line=618'>619</a>     threads=self.nthread,
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/core.py?line=619'>620</a>     feature_names=feature_names,
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/core.py?line=620'>621</a>     feature_types=feature_types,
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/core.py?line=621'>622</a>     enable_categorical=enable_categorical,
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/core.py?line=622'>623</a> )
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/core.py?line=623'>624</a> assert handle is not None
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/core.py?line=624'>625</a> self.handle = handle
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/data.py:703, in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical)
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/data.py?line=700'>701</a>     return _from_uri(data, missing, feature_names, feature_types)
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/data.py?line=701'>702</a> if _is_list(data):
# --> <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/data.py?line=702'>703</a>     return _from_list(data, missing, threads, feature_names, feature_types)
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/data.py?line=703'>704</a> if _is_tuple(data):
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/data.py?line=704'>705</a>     return _from_tuple(data, missing, threads, feature_names, feature_types)
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/data.py:635, in _from_list(data, missing, n_threads, feature_names, feature_types)
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/data.py?line=632'>633</a> array = np.array(data)
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/data.py?line=633'>634</a> _check_data_shape(data)
# --> <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/data.py?line=634'>635</a> return _from_numpy_array(array, missing, n_threads, feature_names, feature_types)
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/data.py:168, in _from_numpy_array(data, missing, nthread, feature_names, feature_types)
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/data.py?line=163'>164</a> """Initialize data from a 2-D numpy matrix.
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/data.py?line=164'>165</a>
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/data.py?line=165'>166</a> """
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/data.py?line=166'>167</a> if len(data.shape) != 2:
# --> <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/data.py?line=167'>168</a>     raise ValueError(
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/data.py?line=168'>169</a>         "Expecting 2 dimensional numpy.ndarray, got: ", data.shape
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/data.py?line=169'>170</a>     )
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/data.py?line=170'>171</a> data, _ = _ensure_np_dtype(data, data.dtype)
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/xgboost/data.py?line=171'>172</a> handle = ctypes.c_void_p()
#
# ValueError: ('Expecting 2 dimensional numpy.ndarray, got: ', (4,))

# %% [markdown]
# ### 모든지역 데이터를 한개의 df로 리턴해주는 함수

# %%
# 모든지역 데이터 return
def predict_6m_all_region(start_month, pred_year):
    df = pd.DataFrame()
    for mon in range(start_month, start_month+6):
        region_data = []
        for region in df_weather['조사지역'].unique():
            pred_data = OLS_model_predict(region, mon, pred_year)
            tmp_data =[]
            for data in pred_data :
                tmp_data.append(data[-1])
            tmp_data.append(region)
            region_data.append(tmp_data)

        # print(tmp_data)
        df_pred  = predict_crops_6m(region_data)
        df = pd.concat([df, df_pred])
        df_gr = df.groupby(df.index).mean()
        for col in df_gr.columns :
            df_gr = df_gr.sort_values(by=col, ascending=False)
        
    return df_gr

def predict_crops_6m(data):
    tmp_grain = df_grain[['temperature', 'temp_max', 'temp_min',  'rainfall', 'label']]
    xgb = XGBClassifier(booster = 'gbtree', learning_rate = 0.01, n_estimators = 10)  
    labelencoder = LabelEncoder()
    target_lb = labelencoder.fit_transform(tmp_grain.label)
    scaler = MinMaxScaler()
    grain_data = tmp_grain[tmp_grain.columns[:-1]]

    for value in data:
        grain_data= grain_data.append({'temperature' :  value[0], 'temp_max' : value[1], 'temp_min' : value[2], 'rainfall' : value[3]*30} , ignore_index=True)

    grain_mmx = scaler.fit_transform(grain_data)

    # display(grain_data.tail())
    # display(grain_mmx[:-1])
    # display(grain_mmx[-1])

    X_train, X_test, y_train, y_test = train_test_split(
        grain_mmx[:-len(data)], target_lb, stratify=target_lb, test_size=0.2,
        random_state=2022
    )
    xgb.fit(X_train, y_train)

    # print(grain_mmx[-1])
    return_pred = pd.DataFrame()
    for i, value in enumerate(data):
        df_pred = pd.DataFrame(xgb.predict_proba(grain_mmx[-(len(data)-i)].reshape(1,-1)), columns=labelencoder.classes_).T
        df_pred.columns = [value[4]]
        # df_pred = df_pred.sort_values(by='확률',ascending=False)
        return_pred = pd.concat([return_pred, df_pred], axis=1)
    return return_pred

def OLS_model_predict(region, month, pred_year):
    df_tmp_region = df_weather[df_weather['조사지역'] == region]
    df_weather_region = df_tmp_region.groupby(['조사지역', '관측일자']).mean()
    df_weather_region = df_weather_region.reset_index(drop=False)

    df_group_mean = df_weather_region.groupby(['연', '월']).mean()
    df_group_mean = df_group_mean.reset_index(drop=False)
    df_month_mean = df_group_mean[df_group_mean['월'] == month]

    for i in df_month_mean.index:
        df_tmp = df_weather_region.loc[(df_weather_region['연'] == df_month_mean.loc[i, '연']) & (df_weather_region['월'] == df_month_mean.loc[i, '월'])]
        temp_max = df_tmp['temp_max'].max()
        temp_min = df_tmp['temp_min'].min()
        df_month_mean.loc[i, 'temp_max'] = temp_max
        df_month_mean.loc[i, 'temp_min'] = temp_min

    pred_list = []
    for value in df_month_mean.columns[2: -2]:
        df_target = df_month_mean[value]
        X_train2 = pd.DataFrame(df_month_mean[['연']], columns = ['연'])
        y_train2 = df_target.values

        # import statsmodels.api as sm
        X_train = sm.add_constant(X_train2)
        model = sm.OLS(y_train2, X_train2).fit()
        pred_value = model.predict(pred_year)
        pred_list.append([region, float(pred_value)])

    # print(f'\t\t\t{region}의 {month}월 {pred_year}의 예측값:')
    # print(pred_list)
    return pred_list

# %%
def top3(data):
    df_all = pd.DataFrame()
    for col in data.columns:  
        df_tmp = pred_list[[col]]
        # display(df_tmp)
        df_tmp= df_tmp.sort_values(by=col, ascending=False)
        # display(df_tmp)
        # display(df_tmp.head(3).index)
        df_co = pd.DataFrame(df_tmp.head(3).index, columns = [col])
        df_co.index = [1, 2, 3]
        df_all = pd.concat([df_all, df_co], axis=1)

    return df_all
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# %time predict_6m_all_region(4, 2100)
# Out:
# [13:49:11] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:54:07] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:57:57] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:02:22] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:06:03] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:10:00] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# CPU times: user 23min 11s, sys: 1min 44s, total: 24min 55s
# Wall time: 27min 9s
#                    서울       관악산        춘천        철원        속초        원주  \
# coconut      0.031503  0.024379  0.024458  0.024446  0.024569  0.024279
# pomegranate  0.024228  0.024378  0.024457  0.024444  0.024567  0.031899
# 딸기           0.032032  0.024385  0.024464  0.024452  0.032127  0.024285
# maize        0.024276  0.029885  0.029711  0.029953  0.029822  0.029533
# 멜론           0.032049  0.028472  0.032644  0.032621  0.028671  0.032285
# rice         0.024322  0.024427  0.024551  0.024538  0.024662  0.024370
# chickpea     0.024264  0.024447  0.024491  0.024480  0.024637  0.024348
# 토마토          0.024235  0.024425  0.024505  0.024454  0.024574  0.024285
# cocoa        0.024320  0.024423  0.024542  0.024530  0.024654  0.024362
# banana       0.031504  0.024379  0.024458  0.024446  0.024569  0.024279
# 고추           0.024521  0.024388  0.024783  0.024764  0.024584  0.024301
# 호박           0.024242  0.024387  0.024477  0.024459  0.024582  0.024298
# 참외           0.024242  0.024387  0.024476  0.024459  0.024582  0.024298
# 오이           0.024242  0.024387  0.024476  0.024459  0.024582  0.024298
# kidneybeans  0.024239  0.031838  0.024470  0.024458  0.024579  0.024289
# 상추           0.024258  0.024432  0.024470  0.024478  0.024581  0.024308
# cotton       0.024237  0.024379  0.024458  0.024446  0.024569  0.024279
# 가지           0.024238  0.024385  0.024470  0.024454  0.024577  0.024291
# wheat        0.024235  0.024385  0.024463  0.024451  0.024574  0.024285
# 마늘           0.024235  0.024385  0.024463  0.024492  0.024574  0.024284
# 양파           0.024234  0.024384  0.024462  0.024454  0.024573  0.024284
# 무            0.024233  0.024386  0.024461  0.024449  0.024572  0.024283
# 시금치          0.024233  0.024386  0.024461  0.024449  0.024572  0.024283
# 매실           0.024229  0.031837  0.032021  0.032253  0.024569  0.031843
# 레빗아이 블루베리    0.024229  0.024379  0.024457  0.024445  0.024568  0.024279
# papaya       0.024229  0.024379  0.024457  0.024445  0.024568  0.024279
# 복숭아          0.024229  0.024379  0.024457  0.024445  0.024568  0.024278
# coffee       0.024229  0.024379  0.024457  0.024445  0.024568  0.024278
# apple        0.024229  0.024379  0.024457  0.024445  0.024568  0.024278
# watermelon   0.024228  0.024379  0.024457  0.024445  0.024568  0.024278
# 감            0.024228  0.024379  0.024457  0.024445  0.024568  0.024278
# lentil       0.024228  0.024379  0.024457  0.024445  0.024568  0.024278
# 살구           0.024228  0.024378  0.024457  0.024445  0.024567  0.024278
# 베            0.024228  0.024378  0.024457  0.024444  0.024567  0.024278
# mango        0.024228  0.024378  0.024457  0.024444  0.024567  0.024278
# 배추           0.024228  0.024378  0.024457  0.024444  0.024567  0.024278
# muskmelon    0.024228  0.024378  0.024456  0.024444  0.024567  0.024278
# grapes       0.024228  0.024378  0.024456  0.024444  0.024567  0.024278
# 하이부시 블루베리    0.024228  0.024378  0.024456  0.024444  0.024567  0.024278
# orange       0.024228  0.024378  0.024456  0.024444  0.024567  0.024278
#
#                   대관령        태백        인제        홍천  ...        포항       울릉도  \
# coconut      0.024408  0.024484  0.024466  0.024279  ...  0.039007  0.024409
# pomegranate  0.024407  0.024482  0.024465  0.031899  ...  0.039011  0.024407
# 딸기           0.032218  0.024531  0.024472  0.024286  ...  0.024147  0.032210
# maize        0.024460  0.029988  0.029719  0.029533  ...  0.029611  0.024462
# 멜론           0.024410  0.024485  0.032657  0.032282  ...  0.024137  0.024410
# rice         0.024410  0.024485  0.024513  0.024370  ...  0.024192  0.024417
# chickpea     0.024443  0.024551  0.024535  0.024313  ...  0.024176  0.024409
# 토마토          0.024461  0.024533  0.024474  0.024288  ...  0.024111  0.024414
# cocoa        0.024410  0.024485  0.024509  0.024362  ...  0.024117  0.040052
# banana       0.024408  0.024484  0.024466  0.024279  ...  0.024183  0.024409
# 고추           0.024410  0.024485  0.024488  0.024301  ...  0.024127  0.024410
# 호박           0.024410  0.024485  0.024485  0.024298  ...  0.024124  0.024410
# 참외           0.024410  0.024485  0.024484  0.024298  ...  0.024123  0.024410
# 오이           0.024410  0.024485  0.024484  0.024298  ...  0.024123  0.024410
# kidneybeans  0.024431  0.031944  0.024478  0.024289  ...  0.024115  0.024434
# 상추           0.024428  0.024520  0.024498  0.024291  ...  0.024134  0.024480
# cotton       0.024408  0.024484  0.024466  0.024279  ...  0.024122  0.024409
# 가지           0.024410  0.024485  0.024478  0.024291  ...  0.024117  0.024410
# wheat        0.024418  0.024493  0.024471  0.024285  ...  0.024111  0.024414
# 마늘           0.032222  0.024493  0.024513  0.024327  ...  0.024111  0.024414
# 양파           0.024420  0.024491  0.024474  0.024288  ...  0.024110  0.024413
# 무            0.024415  0.024491  0.024469  0.024283  ...  0.024109  0.024416
# 시금치          0.024415  0.024491  0.024469  0.024283  ...  0.024109  0.024416
# 매실           0.032213  0.031941  0.032029  0.031843  ...  0.024105  0.024409
# 레빗아이 블루베리    0.024408  0.024483  0.024465  0.024279  ...  0.024105  0.024408
# papaya       0.024407  0.024483  0.024465  0.024279  ...  0.024105  0.024408
# 복숭아          0.024407  0.024483  0.024465  0.024279  ...  0.024105  0.024408
# coffee       0.024428  0.024483  0.024465  0.024279  ...  0.024105  0.024428
# apple        0.024415  0.024483  0.024465  0.024279  ...  0.024105  0.024415
# watermelon   0.024407  0.024483  0.024465  0.024279  ...  0.024105  0.024408
# 감            0.024407  0.024483  0.024465  0.024279  ...  0.024104  0.024408
# lentil       0.024407  0.024483  0.024465  0.024279  ...  0.024104  0.024408
# 살구           0.024407  0.024482  0.024465  0.024278  ...  0.024104  0.024407
# 베            0.024407  0.024482  0.024465  0.024278  ...  0.024104  0.024407
# mango        0.024407  0.024482  0.024465  0.024278  ...  0.024104  0.024407
# 배추           0.024407  0.024482  0.024465  0.024278  ...  0.024104  0.024407
# muskmelon    0.024407  0.024482  0.024464  0.024278  ...  0.024104  0.024407
# grapes       0.024407  0.024482  0.024464  0.024278  ...  0.024104  0.024407
# 하이부시 블루베리    0.024407  0.024482  0.024464  0.024278  ...  0.024104  0.024407
# orange       0.024407  0.024482  0.024464  0.024278  ...  0.024104  0.024407
#
#                    동해        영월       흑산도       동두천        문산        진도  \
# coconut      0.024534  0.024279  0.032031  0.024375  0.024454  0.024604
# pomegranate  0.024533  0.031898  0.024227  0.024374  0.024452  0.024603
# 딸기           0.032092  0.024285  0.024229  0.024381  0.024460  0.032409
# maize        0.035254  0.029532  0.024279  0.029628  0.029967  0.024606
# 멜론           0.024557  0.032281  0.024230  0.032477  0.032636  0.024606
# rice         0.024629  0.024369  0.024278  0.024467  0.024546  0.024697
# chickpea     0.024602  0.024347  0.024295  0.024408  0.024488  0.024605
# 토마토          0.024539  0.024287  0.024233  0.024422  0.024499  0.024610
# cocoa        0.024620  0.024361  0.024251  0.024458  0.024538  0.032467
# banana       0.024534  0.024279  0.024237  0.024375  0.024454  0.024604
# 고추           0.024549  0.024300  0.024230  0.028102  0.024469  0.024606
# 호박           0.024547  0.024297  0.024230  0.024394  0.024467  0.024606
# 참외           0.024547  0.024297  0.024230  0.024393  0.024466  0.024606
# 오이           0.024547  0.024297  0.024230  0.024393  0.024466  0.024606
# kidneybeans  0.024544  0.024291  0.032050  0.024387  0.024466  0.024608
# 상추           0.024546  0.024291  0.024297  0.024387  0.024466  0.024637
# cotton       0.024534  0.024279  0.024237  0.024375  0.024454  0.024604
# 가지           0.024543  0.024290  0.024230  0.024387  0.024462  0.024606
# wheat        0.024539  0.024284  0.024229  0.024380  0.024459  0.024610
# 마늘           0.024539  0.024326  0.031680  0.024380  0.024459  0.024610
# 양파           0.024538  0.024287  0.024233  0.024380  0.024458  0.024609
# 무            0.024538  0.024282  0.024246  0.024379  0.024457  0.024612
# 시금치          0.024538  0.024282  0.024246  0.024379  0.024457  0.024612
# 매실           0.024534  0.031842  0.024228  0.031938  0.032261  0.024604
# 레빗아이 블루베리    0.024533  0.024278  0.024228  0.024374  0.024453  0.024604
# papaya       0.024533  0.024278  0.024228  0.024374  0.024453  0.024604
# 복숭아          0.024533  0.024278  0.024227  0.024374  0.024453  0.024604
# coffee       0.024533  0.024278  0.024247  0.024374  0.024453  0.024604
# apple        0.024533  0.024278  0.024235  0.024374  0.024453  0.024604
# watermelon   0.024533  0.024278  0.024227  0.024374  0.024453  0.024603
# 감            0.024533  0.024278  0.024227  0.024374  0.024453  0.024603
# lentil       0.024533  0.024278  0.024227  0.024374  0.024453  0.024603
# 살구           0.024533  0.024277  0.024227  0.024374  0.024453  0.024603
# 베            0.024533  0.024277  0.024227  0.024374  0.024452  0.024603
# mango        0.024533  0.024277  0.024227  0.024374  0.024452  0.024603
# 배추           0.024533  0.024277  0.031680  0.024374  0.024452  0.024603
# muskmelon    0.024532  0.024277  0.024227  0.024374  0.024452  0.024603
# grapes       0.024532  0.024277  0.024227  0.024373  0.024452  0.024603
# 하이부시 블루베리    0.024532  0.024277  0.024227  0.024373  0.024452  0.024603
# orange       0.024532  0.024277  0.024227  0.024373  0.024452  0.024603
#
#                    상주        고창
# coconut      0.024554  0.031986
# pomegranate  0.032355  0.031806
# 딸기           0.024596  0.031745
# maize        0.030055  0.029446
# 멜론           0.028667  0.028102
# rice         0.024646  0.024276
# chickpea     0.024624  0.024255
# 토마토          0.024559  0.024233
# cocoa        0.024637  0.024233
# banana       0.024554  0.024227
# 고추           0.024576  0.024201
# 호박           0.024573  0.024199
# 참외           0.024572  0.024199
# 오이           0.024572  0.024199
# kidneybeans  0.024566  0.024199
# 상추           0.024583  0.024198
# cotton       0.024554  0.024195
# 가지           0.024566  0.024195
# wheat        0.024559  0.024192
# 마늘           0.024559  0.024192
# 양파           0.024559  0.024191
# 무            0.024558  0.024190
# 시금치          0.024558  0.024190
# 매실           0.024554  0.024186
# 레빗아이 블루베리    0.024553  0.024186
# papaya       0.024553  0.024186
# 복숭아          0.024553  0.024186
# coffee       0.024553  0.024186
# apple        0.024553  0.024186
# watermelon   0.024553  0.024186
# 감            0.024553  0.024186
# lentil       0.024553  0.024185
# 살구           0.024553  0.024185
# 베            0.024553  0.024185
# mango        0.024553  0.024185
# 배추           0.024553  0.024185
# muskmelon    0.024552  0.024185
# grapes       0.024552  0.024185
# 하이부시 블루베리    0.024552  0.024185
# orange       0.024552  0.024185
#
# [40 rows x 73 columns]

# %% [markdown]
# ### xgbooster best_params 추출
# - 시계열 데이터의 특성을 고려하여 해당월의 classifier를 다 따로 돌림

# %%
# OLS_model_predict(region, month, pred_year):
region = '서울'
month = 6
pred_year = 2022

df_tmp_region = df_weather[df_weather['조사지역'] == region]
df_weather_region = df_tmp_region.groupby(['조사지역', '관측일자']).mean()
df_weather_region = df_weather_region.reset_index(drop=False)

df_group_mean = df_weather_region.groupby(['연', '월']).mean()
df_group_mean = df_group_mean.reset_index(drop=False)
df_month_mean = df_group_mean[df_group_mean['월'] == month]

for i in df_month_mean.index:
    df_tmp = df_weather_region.loc[(df_weather_region['연'] == df_month_mean.loc[i, '연']) & (df_weather_region['월'] == df_month_mean.loc[i, '월'])]
    temp_max = df_tmp['temp_max'].max()
    temp_min = df_tmp['temp_min'].min()
    df_month_mean.loc[i, 'temp_max'] = temp_max
    df_month_mean.loc[i, 'temp_min'] = temp_min

pred_list = []
for value in df_month_mean.columns[2: -1]:
    df_target = df_month_mean[value]
    X_train2 = pd.DataFrame(df_month_mean[['연']], columns = ['연'])
    y_train2 = df_target.values

    # import statsmodels.api as sm
    X_train = sm.add_constant(X_train2)
    model = sm.OLS(y_train2, X_train2).fit()
    pred_value = model.predict(pred_year)
    pred_list.append([value, float(pred_value)])

# print(f'\t\t\t{region}의 {month}월 {pred_year}의 예측값:')
# print(pred_list)
pred_list
# Out:
# [['temperature', 22.80263004569429],
#  ['temp_max', 32.66101643862828],
#  ['temp_min', 14.510903067907272],
#  ['rainfall', 4.682851271821746],
#  ['humidity', 67.1027178427563]]

# %%
from sklearn.model_selection import GridSearchCV
XGBClassifier().get_params()
# Out:
# {'base_score': 0.5,
#  'booster': 'gbtree',
#  'colsample_bylevel': 1,
#  'colsample_bynode': 1,
#  'colsample_bytree': 1,
#  'gamma': 0,
#  'learning_rate': 0.1,
#  'max_delta_step': 0,
#  'max_depth': 3,
#  'min_child_weight': 1,
#  'missing': None,
#  'n_estimators': 100,
#  'n_jobs': 1,
#  'nthread': None,
#  'objective': 'binary:logistic',
#  'random_state': 0,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'scale_pos_weight': 1,
#  'seed': None,
#  'silent': None,
#  'subsample': 1,
#  'verbosity': 1}

# %%
pred_data = pred_list
tmp_data =[]
for data in pred_data :
    tmp_data.append(data[-1])

data = tmp_data
tmp_grain = df_grain[['temperature', 'temp_max', 'temp_min',  'rainfall', 'label']]



labelencoder = LabelEncoder()
target_lb = labelencoder.fit_transform(tmp_grain.label)
scaler = MinMaxScaler()
grain_data = tmp_grain[tmp_grain.columns[:-1]]

grain_data= grain_data.append({'temperature' :  data[0], 'temp_max' : data[1], 'temp_min' : data[2], 'rainfall' : data[3]*30} , ignore_index=True)

grain_mmx = scaler.fit_transform(grain_data)

# display(grain_data.tail())
# display(grain_mmx[:-1])
# display(grain_mmx[-1])

X_train, X_test, y_train, y_test = train_test_split(
    grain_mmx[:-1], target_lb, stratify=target_lb, test_size=0.2,
    random_state=2022
)

xgb = XGBClassifier()  
params = {
    'booster' : ['gbtree', 'gblinear'],
    'n_estimators' : [10, 100, 1000],
    'learning_rate' : [0.01, 0.05, 0.1]
}

xgb_grid = GridSearchCV(
    xgb, params, scoring='accuracy', cv=5
)


xgb_grid.fit(X_train, y_train)

print(xgb_grid.best_score_, xgb_grid.best_params_)
xgb_best = xgb_grid.best_estimator_

# print(grain_mmx[-1])
df_pred = pd.DataFrame(xgb_best.predict_proba(list(grain_mmx[-1])), columns=labelencoder.classes_).T
df_pred.columns = ['확률']
df_pred = df_pred.sort_values(by='확률',ascending=False)
return_pred = df_pred
return_pred
# Out:
# 0.9953968938740294 {'booster': 'gbtree', 'learning_rate': 0.01, 'n_estimators': 10}
#                    확률
# cocoa        0.076987
# coconut      0.051366
# cotton       0.051278
# banana       0.051278
# maize        0.051278
# papaya       0.051275
# kidneybeans  0.051274
# watermelon   0.051274
# chickpea     0.051274
# lentil       0.051273
# apple        0.051273
# coffee       0.051273
# rice         0.051272
# mango        0.051272
# pomegranate  0.051272
# muskmelon    0.051271
# orange       0.051271
# grapes       0.051271
# wheat        0.051270

# %%
# xgbooster GridSearch 샘플 10개만 (너무 오래 걸림)
def xgboost_best_params(start_month, pred_year):
    sample_list = np.random.choice(72, 10)
    df = pd.DataFrame()
    for mon in range(start_month, start_month+6):
        region_data = []
        for region in df_weather['조사지역'].unique()[sample_list]:
            pred_data = OLS_model_predict(region, mon, pred_year)
            tmp_data =[]
            for data in pred_data :
                tmp_data.append(data[-1])
            tmp_data.append(region)
            region_data.append(tmp_data)

        # print(tmp_data)
        df_pred  = xgboost_params(region_data)
        df = pd.concat([df, df_pred])
        df_gr = df.groupby(df.index).mean()
        for col in df_gr.columns :
            df_gr = df_gr.sort_values(by=col, ascending=False)
        
    return df_gr

def xgboost_params(data):
    tmp_grain = df_grain[['temperature', 'temp_max', 'temp_min',  'rainfall', 'label']]

    labelencoder = LabelEncoder()
    target_lb = labelencoder.fit_transform(tmp_grain.label)
    scaler = MinMaxScaler()
    grain_data = tmp_grain[tmp_grain.columns[:-1]]

    for value in data:
        grain_data= grain_data.append({'temperature' :  value[0], 'temp_max' : value[1], 'temp_min' : value[2], 'rainfall' : value[3]*30} , ignore_index=True)

    grain_mmx = scaler.fit_transform(grain_data)

    # display(grain_data.tail())
    # display(grain_mmx[:-1])
    # display(grain_mmx[-1])

    X_train, X_test, y_train, y_test = train_test_split(
        grain_mmx[:-len(data)], target_lb, stratify=target_lb, test_size=0.2,
        random_state=2022
    )


    xgb = XGBClassifier()  
    params = {
        'booster' : ['gbtree', 'gblinear'],
        'n_estimators' : [10, 100, 1000],
        'learning_rate' : [0.01, 0.05, 0.1]
    }

    xgb_grid = GridSearchCV(
        xgb, params, scoring='accuracy', cv=5
    )

    xgb_grid.fit(X_train, y_train)

    print(xgb_grid.best_score_, xgb_grid.best_params_)
    xgb_best = xgb_grid.best_estimator_

    # print(grain_mmx[-1])
    return_pred = pd.DataFrame()
    for i, value in enumerate(data):
        df_pred = pd.DataFrame(xgb_best.predict_proba(list(grain_mmx[-(len(data)-i)])), columns=labelencoder.classes_).T
        df_pred.columns = [value[4]]
        # df_pred = df_pred.sort_values(by='확률',ascending=False)
        return_pred = pd.concat([return_pred, df_pred], axis=1)
    return return_pred

def OLS_model_predict(region, month, pred_year):
    df_tmp_region = df_weather[df_weather['조사지역'] == region]
    df_weather_region = df_tmp_region.groupby(['조사지역', '관측일자']).mean()
    df_weather_region = df_weather_region.reset_index(drop=False)

    df_group_mean = df_weather_region.groupby(['연', '월']).mean()
    df_group_mean = df_group_mean.reset_index(drop=False)
    df_month_mean = df_group_mean[df_group_mean['월'] == month]

    for i in df_month_mean.index:
        df_tmp = df_weather_region.loc[(df_weather_region['연'] == df_month_mean.loc[i, '연']) & (df_weather_region['월'] == df_month_mean.loc[i, '월'])]
        temp_max = df_tmp['temp_max'].max()
        temp_min = df_tmp['temp_min'].min()
        df_month_mean.loc[i, 'temp_max'] = temp_max
        df_month_mean.loc[i, 'temp_min'] = temp_min

    pred_list = []
    for value in df_month_mean.columns[2: -2]:
        df_target = df_month_mean[value]
        X_train2 = pd.DataFrame(df_month_mean[['연']], columns = ['연'])
        y_train2 = df_target.values

        # import statsmodels.api as sm
        X_train = sm.add_constant(X_train2)
        model = sm.OLS(y_train2, X_train2).fit()
        pred_value = model.predict(pred_year)
        pred_list.append([region, float(pred_value)])

    # print(f'\t\t\t{region}의 {month}월 {pred_year}의 예측값:')
    # print(pred_list)
    return pred_list

# %%
xgboost_best_params(3, 2022)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6개월 지역 작물 예측 모델.ipynb Cell 19' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000018?line=0'>1</a> xgboost_best_params(3, 2022)
#
# /Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6개월 지역 작물 예측 모델.ipynb Cell 18' in xgboost_best_params(start_month, pred_year)
#       <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000017?line=5'>6</a> region_data = []
#       <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000017?line=6'>7</a> for region in df_weather['조사지역'].unique()[sample_list]:
# ----> <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000017?line=7'>8</a>     pred_data = OLS_model_predict(region, mon, pred_year)
#       <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000017?line=8'>9</a>     tmp_data =[]
#      <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000017?line=9'>10</a>     for data in pred_data :
#
# /Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6개월 지역 작물 예측 모델.ipynb Cell 18' in OLS_model_predict(region, month, pred_year)
#      <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000017?line=83'>84</a>     temp_min = df_tmp['temp_min'].min()
#      <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000017?line=84'>85</a>     df_month_mean.loc[i, 'temp_max'] = temp_max
# ---> <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000017?line=85'>86</a>     df_month_mean.loc[i, 'temp_min'] = temp_min
#      <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000017?line=87'>88</a> pred_list = []
#      <a href='vscode-notebook-cell:/Users/wondongchan/Desktop/multi/FlaskPractice2/0511_6%EA%B0%9C%EC%9B%94%20%EC%A7%80%EC%97%AD%20%EC%9E%91%EB%AC%BC%20%EC%98%88%EC%B8%A1%20%EB%AA%A8%EB%8D%B8.ipynb#ch0000017?line=88'>89</a> for value in df_month_mean.columns[2: -2]:
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/indexing.py:716, in _LocationIndexer.__setitem__(self, key, value)
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/indexing.py?line=712'>713</a> self._has_valid_setitem_indexer(key)
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/indexing.py?line=714'>715</a> iloc = self if self.name == "iloc" else self.obj.iloc
# --> <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/indexing.py?line=715'>716</a> iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/indexing.py:1690, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/indexing.py?line=1687'>1688</a>     self._setitem_with_indexer_split_path(indexer, value, name)
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/indexing.py?line=1688'>1689</a> else:
# -> <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/indexing.py?line=1689'>1690</a>     self._setitem_single_block(indexer, value, name)
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/indexing.py:1935, in _iLocIndexer._setitem_single_block(self, indexer, value, name)
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/indexing.py?line=1931'>1932</a>     value = self._align_frame(indexer, value)
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/indexing.py?line=1933'>1934</a> # check for chained assignment
# -> <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/indexing.py?line=1934'>1935</a> self.obj._check_is_chained_assignment_possible()
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/indexing.py?line=1936'>1937</a> # actually do the set
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/indexing.py?line=1937'>1938</a> self.obj._mgr = self.obj._mgr.setitem(indexer=indexer, value=value)
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/generic.py:3957, in NDFrame._check_is_chained_assignment_possible(self)
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/generic.py?line=3945'>3946</a> """
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/generic.py?line=3946'>3947</a> Check if we are a view, have a cacher, and are of mixed type.
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/generic.py?line=3947'>3948</a> If so, then force a setitem_copy check.
#    (...)
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/generic.py?line=3953'>3954</a> setting.
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/generic.py?line=3954'>3955</a> """
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/generic.py?line=3955'>3956</a> if self._is_copy:
# -> <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/generic.py?line=3956'>3957</a>     self._check_setitem_copy(t="referent")
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/generic.py?line=3957'>3958</a> return False
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/generic.py:4030, in NDFrame._check_setitem_copy(self, t, force)
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/generic.py?line=4027'>4028</a>     raise com.SettingWithCopyError(t)
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/generic.py?line=4028'>4029</a> elif value == "warn":
# -> <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/core/generic.py?line=4029'>4030</a>     warnings.warn(t, com.SettingWithCopyWarning, stacklevel=find_stack_level())
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/util/_exceptions.py:32, in find_stack_level()
#      <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/util/_exceptions.py?line=26'>27</a> def find_stack_level() -> int:
#      <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/util/_exceptions.py?line=27'>28</a>     """
#      <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/util/_exceptions.py?line=28'>29</a>     Find the first place in the stack that is not inside pandas
#      <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/util/_exceptions.py?line=29'>30</a>     (tests notwithstanding).
#      <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/util/_exceptions.py?line=30'>31</a>     """
# ---> <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/util/_exceptions.py?line=31'>32</a>     stack = inspect.stack()
#      <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/util/_exceptions.py?line=33'>34</a>     import pandas as pd
#      <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/site-packages/pandas/util/_exceptions.py?line=35'>36</a>     pkg_dir = os.path.dirname(pd.__file__)
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py:1552, in stack(context)
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=1549'>1550</a> def stack(context=1):
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=1550'>1551</a>     """Return a list of records for the stack above the caller's frame."""
# -> <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=1551'>1552</a>     return getouterframes(sys._getframe(1), context)
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py:1529, in getouterframes(frame, context)
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=1526'>1527</a> framelist = []
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=1527'>1528</a> while frame:
# -> <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=1528'>1529</a>     frameinfo = (frame,) + getframeinfo(frame, context)
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=1529'>1530</a>     framelist.append(FrameInfo(*frameinfo))
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=1530'>1531</a>     frame = frame.f_back
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py:1503, in getframeinfo(frame, context)
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=1500'>1501</a> start = lineno - 1 - context//2
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=1501'>1502</a> try:
# -> <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=1502'>1503</a>     lines, lnum = findsource(frame)
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=1503'>1504</a> except OSError:
#    <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=1504'>1505</a>     lines = index = None
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py:829, in findsource(object)
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=825'>826</a>     if not (file.startswith('<') and file.endswith('>')):
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=826'>827</a>         raise OSError('source code not available')
# --> <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=828'>829</a> module = getmodule(object, file)
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=829'>830</a> if module:
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=830'>831</a>     lines = linecache.getlines(file, module.__dict__)
#
# File ~/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py:746, in getmodule(object, _filename)
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=742'>743</a> # Update the filename to module name cache and check yet again
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=743'>744</a> # Copy sys.modules in order to cope with changes while iterating
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=744'>745</a> for modname, module in sys.modules.copy().items():
# --> <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=745'>746</a>     if ismodule(module) and hasattr(module, '__file__'):
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=746'>747</a>         f = module.__file__
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=747'>748</a>         if f == _filesbymodname.get(modname, None):
#     <a href='file:///Users/wondongchan/opt/anaconda3/envs/kdig/lib/python3.9/inspect.py?line=748'>749</a>             # Have already mapped this module, so skip it
#
# KeyboardInterrupt:

# %% [markdown]
# ### LGBMClassifier 사용

# %%
# lgbm GridSearch 샘플 10개만 (너무 오래 걸림)
def lgbm_best_params(start_month, pred_year):
    sample_list = np.random.choice(72, 10)
    df = pd.DataFrame()
    for mon in range(start_month, start_month+6):
        region_data = []
        for region in df_weather['조사지역'].unique()[sample_list]:
            pred_data = OLS_model_predict(region, mon, pred_year)
            tmp_data =[]
            for data in pred_data :
                tmp_data.append(data[-1])
            tmp_data.append(region)
            region_data.append(tmp_data)

        # print(tmp_data)
        df_pred  = lgbm_params(region_data)
        df = pd.concat([df, df_pred])
        df_gr = df.groupby(df.index).mean()
        for col in df_gr.columns :
            df_gr = df_gr.sort_values(by=col, ascending=False)
        
    return df_gr

def lgbm_params(data):
    tmp_grain = df_grain[['temperature', 'temp_max', 'temp_min',  'rainfall', 'label']]

    labelencoder = LabelEncoder()
    target_lb = labelencoder.fit_transform(tmp_grain.label)
    scaler = MinMaxScaler()
    grain_data = tmp_grain[tmp_grain.columns[:-1]]

    for value in data:
        grain_data= grain_data.append({'temperature' :  value[0], 'temp_max' : value[1], 'temp_min' : value[2], 'rainfall' : value[3]*30} , ignore_index=True)

    grain_mmx = scaler.fit_transform(grain_data)

    # display(grain_data.tail())
    # display(grain_mmx[:-1])
    # display(grain_mmx[-1])

    X_train, X_test, y_train, y_test = train_test_split(
        grain_mmx[:-len(data)], target_lb, stratify=target_lb, test_size=0.2,
        random_state=2022
    )


    lgb = LGBMClassifier() 
    params = {
        # 'boosting ' : ['gbdt', 'rf'],
        'n_estimators' : [100, 1000, 1000],
        'learning_rate' : [0.01, 0.05],
        'num_iteration ' : [5, 10, 50]
    }

    lgb_grid = GridSearchCV(
        lgb, params, scoring='accuracy', cv=5
    )



    evals = [(X_test, y_test)]
    lgb_grid.fit(X_train, y_train, eval_set=evals, eval_metric='logloss', verbose=False)

    print(lgb_grid.best_score_, lgb_grid.best_params_)
    lgb_best = lgb_grid.best_estimator_

    # print(grain_mmx[-1])
    return_pred = pd.DataFrame()
    for i, value in enumerate(data):
        df_pred = pd.DataFrame(lgb_best.predict_proba(list(grain_mmx[-(len(data)-i)])), columns=labelencoder.classes_).T
        df_pred.columns = [value[4]]
        # df_pred = df_pred.sort_values(by='확률',ascending=False)
        return_pred = pd.concat([return_pred, df_pred], axis=1)
    return return_pred

def OLS_model_predict(region, month, pred_year):
    df_tmp_region = df_weather[df_weather['조사지역'] == region]
    df_weather_region = df_tmp_region.groupby(['조사지역', '관측일자']).mean()
    df_weather_region = df_weather_region.reset_index(drop=False)

    df_group_mean = df_weather_region.groupby(['연', '월']).mean()
    df_group_mean = df_group_mean.reset_index(drop=False)
    df_month_mean = df_group_mean[df_group_mean['월'] == month]

    for i in df_month_mean.index:
        df_tmp = df_weather_region.loc[(df_weather_region['연'] == df_month_mean.loc[i, '연']) & (df_weather_region['월'] == df_month_mean.loc[i, '월'])]
        temp_max = df_tmp['temp_max'].max()
        temp_min = df_tmp['temp_min'].min()
        df_month_mean.loc[i, 'temp_max'] = temp_max
        df_month_mean.loc[i, 'temp_min'] = temp_min

    pred_list = []
    for value in df_month_mean.columns[2: -2]:
        df_target = df_month_mean[value]
        X_train2 = pd.DataFrame(df_month_mean[['연']], columns = ['연'])
        y_train2 = df_target.values

        # import statsmodels.api as sm
        X_train = sm.add_constant(X_train2)
        model = sm.OLS(y_train2, X_train2).fit()
        pred_value = model.predict(pred_year)
        pred_list.append([region, float(pred_value)])

    # print(f'\t\t\t{region}의 {month}월 {pred_year}의 예측값:')
    # print(pred_list)
    return pred_list

# %%
lgbm_best_params(4, 2022)
# Out:
# 0.9980263157894737 {'learning_rate': 0.01, 'n_estimators': 1000, 'num_iteration ': 5}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-c2bacf5da0c3> in <module>()
# ----> 1 lgbm_best_params(4, 2022)
#
# <ipython-input-121-6bc5d290b845> in lgbm_best_params(start_month, pred_year)
#      14
#      15         # print(tmp_data)
# ---> 16         df_pred  = lgbm_params(region_data)
#      17         df = pd.concat([df, df_pred])
#      18         df_gr = df.groupby(df.index).mean()
#
# <ipython-input-121-6bc5d290b845> in lgbm_params(data)
#      68     return_pred = pd.DataFrame()
#      69     for i, value in enumerate(data):
# ---> 70         df_pred = pd.DataFrame(lgb_best.predict_proba(list(grain_mmx[-(len(data)-i)])), columns=labelencoder.classes_).T
#      71         df_pred.columns = [value[4]]
#      72         # df_pred = df_pred.sort_values(by='확률',ascending=False)
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/sklearn.py in predict_proba(self, X, raw_score, num_iteration, pred_leaf, pred_contrib, **kwargs)
#     798         """
#     799         result = super(LGBMClassifier, self).predict(X, raw_score, num_iteration,
# --> 800                                                      pred_leaf, pred_contrib, **kwargs)
#     801         if self._n_classes > 2 or raw_score or pred_leaf or pred_contrib:
#     802             return result
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/sklearn.py in predict(self, X, raw_score, num_iteration, pred_leaf, pred_contrib, **kwargs)
#     597             raise LGBMNotFittedError("Estimator not fitted, call `fit` before exploiting the model.")
#     598         if not isinstance(X, (DataFrame, DataTable)):
# --> 599             X = _LGBMCheckArray(X, accept_sparse=True, force_all_finite=False)
#     600         n_features = X.shape[1]
#     601         if self._n_features != n_features:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     771                     "Reshape your data either using array.reshape(-1, 1) if "
#     772                     "your data has a single feature or array.reshape(1, -1) "
# --> 773                     "if it contains a single sample.".format(array)
#     774                 )
#     775
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[0.13601561 0.52982154 0.18006621 0.09974333].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
# 모든지역 데이터 return
def predict_6m_all_region_lgb(start_month, pred_year):
    df = pd.DataFrame()
    for mon in range(start_month, start_month+6):
        region_data = []
        for region in df_weather['조사지역'].unique():
            pred_data = OLS_model_predict(region, mon, pred_year)
            tmp_data =[]
            for data in pred_data :
                tmp_data.append(data[-1])
            tmp_data.append(region)
            region_data.append(tmp_data)

        # print(tmp_data)
        df_pred  = predict_crops_6m(region_data)
        df = pd.concat([df, df_pred])
        df_gr = df.groupby(df.index).mean()
        for col in df_gr.columns :
            df_gr = df_gr.sort_values(by=col, ascending=False)
        
    return df_gr

def predict_crops_6m_lgb(data):
    tmp_grain = df_grain[['temperature', 'temp_max', 'temp_min',  'rainfall', 'label']]

    labelencoder = LabelEncoder()
    target_lb = labelencoder.fit_transform(tmp_grain.label)
    scaler = MinMaxScaler()
    grain_data = tmp_grain[tmp_grain.columns[:-1]]

    for value in data:
        grain_data= grain_data.append({'temperature' :  value[0], 'temp_max' : value[1], 'temp_min' : value[2], 'rainfall' : value[3]*30} , ignore_index=True)

    grain_mmx = scaler.fit_transform(grain_data)

    # display(grain_data.tail())
    # display(grain_mmx[:-1])
    # display(grain_mmx[-1])

    X_train, X_test, y_train, y_test = train_test_split(
        grain_mmx[:-len(data)], target_lb, stratify=target_lb, test_size=0.2,
        random_state=2022
    )

    lgb = LGBMClassifier(learning_rate = 0.01, n_estimators = 1000, num_iteration = 5) 

    evals = [(X_test, y_test)]
    lgb.fit(X_train, y_train, eval_set=evals, eval_metric='logloss', verbose=False)


    # print(grain_mmx[-1])
    return_pred = pd.DataFrame()
    for i, value in enumerate(data):
        df_pred = pd.DataFrame(lgb.predict_proba(list(grain_mmx[-(len(data)-i)])), columns=labelencoder.classes_).T
        df_pred.columns = [value[4]]
        # df_pred = df_pred.sort_values(by='확률',ascending=False)
        return_pred = pd.concat([return_pred, df_pred], axis=1)
    return return_pred

def OLS_model_predict(region, month, pred_year):
    df_tmp_region = df_weather[df_weather['조사지역'] == region]
    df_weather_region = df_tmp_region.groupby(['조사지역', '관측일자']).mean()
    df_weather_region = df_weather_region.reset_index(drop=False)

    df_group_mean = df_weather_region.groupby(['연', '월']).mean()
    df_group_mean = df_group_mean.reset_index(drop=False)
    df_month_mean = df_group_mean[df_group_mean['월'] == month]

    for i in df_month_mean.index:
        df_tmp = df_weather_region.loc[(df_weather_region['연'] == df_month_mean.loc[i, '연']) & (df_weather_region['월'] == df_month_mean.loc[i, '월'])]
        temp_max = df_tmp['temp_max'].max()
        temp_min = df_tmp['temp_min'].min()
        df_month_mean.loc[i, 'temp_max'] = temp_max
        df_month_mean.loc[i, 'temp_min'] = temp_min

    pred_list = []
    for value in df_month_mean.columns[2: -2]:
        df_target = df_month_mean[value]
        X_train2 = pd.DataFrame(df_month_mean[['연']], columns = ['연'])
        y_train2 = df_target.values

        # import statsmodels.api as sm
        X_train = sm.add_constant(X_train2)
        model = sm.OLS(y_train2, X_train2).fit()
        pred_value = model.predict(pred_year)
        pred_list.append([region, float(pred_value)])

    # print(f'\t\t\t{region}의 {month}월 {pred_year}의 예측값:')
    # print(pred_list)
    return pred_list

# %%
# %time df = predict_6m_all_region_lgb(3, 2100)
for col in df.columns:
    df = df.sort_values(by=col, ascending=False)
    print(col, '\n', df[col].head(3))
# Out:
# CPU times: user 1min 3s, sys: 441 ms, total: 1min 3s
# Wall time: 1min 4s
# 서울
#  wheat      0.066671
# coconut    0.058220
# banana     0.058210
# Name: 서울, dtype: float32
# 관악산
#  wheat          0.065890
# rice           0.058279
# kidneybeans    0.057813
# Name: 관악산, dtype: float32
# 춘천
#  wheat     0.066810
# lentil    0.058663
# maize     0.057711
# Name: 춘천, dtype: float32
# 철원
#  wheat     0.06640
# grapes    0.05791
# lentil    0.05791
# Name: 철원, dtype: float32
# 속초
#  wheat    0.067379
# cocoa    0.059515
# maize    0.057883
# Name: 속초, dtype: float32
# 원주
#  wheat     0.066593
# lentil    0.058446
# maize     0.057494
# Name: 원주, dtype: float32
# 대관령
#  wheat     0.075296
# grapes    0.058402
# maize     0.057829
# Name: 대관령, dtype: float32
# 태백
#  wheat          0.073527
# cocoa          0.062328
# kidneybeans    0.057393
# Name: 태백, dtype: float32
# 인제
#  wheat     0.074589
# lentil    0.058243
# maize     0.057305
# Name: 인제, dtype: float32
# 홍천
#  wheat     0.074350
# lentil    0.058004
# maize     0.057460
# Name: 홍천, dtype: float32
# 대전
#  wheat      0.067166
# coconut    0.059057
# maize      0.057670
# Name: 대전, dtype: float32
# 금산
#  wheat    0.075360
# maize    0.058073
# cocoa    0.054806
# Name: 금산, dtype: float32
# 부여
#  wheat    0.067386
# maize    0.057890
# cocoa    0.055241
# Name: 부여, dtype: float32
# 천안
#  wheat     0.066585
# cocoa     0.059119
# lentil    0.058439
# Name: 천안, dtype: float32
# 보령
#  wheat          0.065605
# kidneybeans    0.057891
# grapes         0.057514
# Name: 보령, dtype: float32
# 서산
#  wheat          0.065605
# kidneybeans    0.057891
# grapes         0.057514
# Name: 서산, dtype: float32
# 청주
#  wheat      0.066156
# coconut    0.058444
# lentil     0.058009
# Name: 청주, dtype: float32
# 추풍령
#  wheat    0.067358
# cocoa    0.059483
# maize    0.058260
# Name: 추풍령, dtype: float32
# 보은
#  wheat     0.074343
# cocoa     0.058457
# lentil    0.057998
# Name: 보은, dtype: float32
# 제천
#  wheat    0.075097
# maize    0.064462
# rice     0.050669
# Name: 제천, dtype: float32
# 인천
#  wheat      0.064775
# coconut    0.057069
# banana     0.057065
# Name: 인천, dtype: float32
# 강화
#  wheat          0.073256
# kidneybeans    0.057485
# grapes         0.057109
# Name: 강화, dtype: float32
# 수원
#  wheat     0.067122
# lentil    0.058628
# maize     0.058036
# Name: 수원, dtype: float32
# 이천
#  wheat     0.066593
# lentil    0.058446
# maize     0.057494
# Name: 이천, dtype: float32
# 양평
#  wheat     0.066593
# lentil    0.058446
# maize     0.057494
# Name: 양평, dtype: float32
# 광주
#  wheat      0.066533
# coconut    0.066521
# maize      0.057036
# Name: 광주, dtype: float32
# 장흥
#  wheat    0.067913
# maize    0.058429
# cocoa    0.055418
# Name: 장흥, dtype: float32
# 목포
#  wheat      0.065684
# coconut    0.065134
# banana     0.065119
# Name: 목포, dtype: float32
# 해남
#  wheat          0.067122
# kidneybeans    0.058647
# maize          0.058035
# Name: 해남, dtype: float32
# 고흥
#  wheat          0.067118
# kidneybeans    0.058643
# maize          0.058031
# Name: 고흥, dtype: float32
# 완도
#  wheat      0.065455
# coconut    0.064934
# banana     0.064890
# Name: 완도, dtype: float32
# 여수
#  banana     0.065682
# rice       0.058085
# coconut    0.057725
# Name: 여수, dtype: float32
# 전주
#  wheat      0.066949
# coconut    0.058838
# maize      0.057453
# Name: 전주, dtype: float32
# 임실
#  wheat    0.074852
# maize    0.064601
# cocoa    0.054639
# Name: 임실, dtype: float32
# 군산
#  coconut    0.065299
# wheat      0.065058
# banana     0.057022
# Name: 군산, dtype: float32
# 부안
#  wheat      0.065773
# maize      0.063930
# coconut    0.058061
# Name: 부안, dtype: float32
# 정읍
#  wheat    0.067386
# maize    0.057890
# cocoa    0.055241
# Name: 정읍, dtype: float32
# 남원
#  wheat          0.075166
# maize          0.057470
# pomegranate    0.054710
# Name: 남원, dtype: float32
# 장수
#  wheat    0.075566
# maize    0.057687
# cocoa    0.055014
# Name: 장수, dtype: float32
# 부산
#  banana         0.065778
# wheat          0.058190
# kidneybeans    0.058118
# Name: 부산, dtype: float32
# 밀양
#  wheat     0.066950
# orange    0.058805
# maize     0.057453
# Name: 밀양, dtype: float32
# 창원
#  wheat      0.066961
# coconut    0.058598
# maize      0.058148
# Name: 창원, dtype: float32
# 통영
#  wheat      0.065426
# coconut    0.065016
# banana     0.064971
# Name: 통영, dtype: float32
# 거제
#  wheat      0.065761
# coconut    0.065675
# banana     0.057369
# Name: 거제, dtype: float32
# 진주
#  wheat          0.075163
# maize          0.057467
# pomegranate    0.054707
# Name: 진주, dtype: float32
# 산청
#  wheat    0.067386
# maize    0.057890
# cocoa    0.055240
# Name: 산청, dtype: float32
# 남해
#  coconut    0.066450
# wheat      0.066132
# rice       0.057852
# Name: 남해, dtype: float32
# 거창
#  wheat    0.075361
# maize    0.058074
# cocoa    0.054807
# Name: 거창, dtype: float32
# 합천
#  wheat     0.066949
# orange    0.058804
# maize     0.057453
# Name: 합천, dtype: float32
# 울산
#  wheat      0.066533
# coconut    0.066521
# maize      0.057036
# Name: 울산, dtype: float32
# 제주
#  papaya    0.061598
# wheat     0.059790
# cocoa     0.055699
# Name: 제주, dtype: float32
# 고산
#  coconut        0.058619
# kidneybeans    0.058551
# banana         0.058279
# Name: 고산, dtype: float32
# 서귀포
#  banana    0.065942
# papaya    0.059523
# rice      0.058387
# Name: 서귀포, dtype: float32
# 대구
#  orange      0.065496
# wheat       0.065327
# chickpea    0.057644
# Name: 대구, dtype: float32
# 구미
#  wheat     0.066595
# lentil    0.058448
# maize     0.057496
# Name: 구미, dtype: float32
# 문경
#  wheat    0.067581
# maize    0.058494
# cocoa    0.055437
# Name: 문경, dtype: float32
# 영주
#  wheat    0.067581
# maize    0.058494
# cocoa    0.055437
# Name: 영주, dtype: float32
# 봉화
#  wheat    0.074869
# maize    0.064235
# cocoa    0.054665
# Name: 봉화, dtype: float32
# 안동
#  wheat     0.066594
# lentil    0.058447
# maize     0.057495
# Name: 안동, dtype: float32
# 영덕
#  wheat     0.066573
# lentil    0.058426
# maize     0.057883
# Name: 영덕, dtype: float32
# 울진
#  wheat    0.067380
# cocoa    0.059514
# maize    0.057884
# Name: 울진, dtype: float32
# 의성
#  wheat          0.074155
# pomegranate    0.058225
# lentil         0.057809
# Name: 의성, dtype: float32
# 영천
#  wheat          0.066356
# pomegranate    0.058626
# lentil         0.058209
# Name: 영천, dtype: float32
# 포항
#  wheat          0.066319
# coconut        0.066095
# pomegranate    0.057763
# Name: 포항, dtype: float32
# 울릉도
#  wheat     0.067277
# cocoa     0.059460
# grapes    0.058786
# Name: 울릉도, dtype: float32
# 동해
#  wheat    0.067224
# maize    0.064983
# cocoa    0.055076
# Name: 동해, dtype: float32
# 영월
#  wheat     0.074351
# lentil    0.058005
# maize     0.057461
# Name: 영월, dtype: float32
# 흑산도
#  coconut        0.058649
# kidneybeans    0.058646
# wheat          0.057941
# Name: 흑산도, dtype: float32
# 동두천
#  wheat     0.066810
# lentil    0.058663
# maize     0.057711
# Name: 동두천, dtype: float32
# 문산
#  wheat     0.067346
# lentil    0.058852
# maize     0.058260
# Name: 문산, dtype: float32
# 진도
#  wheat          0.066326
# kidneybeans    0.058249
# grapes         0.058232
# Name: 진도, dtype: float32
# 상주
#  wheat     0.066595
# lentil    0.058448
# maize     0.057496
# Name: 상주, dtype: float32
# 고창
#  wheat      0.066155
# coconut    0.058428
# lentil     0.058009
# Name: 고창, dtype: float32

# %%
# %time df_xg = predict_6m_all_region(3, 2022)

for col in df_xg.columns:
    df_xg = df_xg.sort_values(by=col, ascending=False)
    print(col, '\n', df_xg[col].head(3))
# Out:
# CPU times: user 1min 9s, sys: 467 ms, total: 1min 9s
# Wall time: 1min 15s
# 서울
#  wheat          0.065607
# kidneybeans    0.057892
# grapes         0.057516
# Name: 서울, dtype: float32
# 관악산
#  wheat          0.065893
# rice           0.057904
# kidneybeans    0.057816
# Name: 관악산, dtype: float32
# 춘천
#  wheat     0.066429
# maize     0.064586
# lentil    0.058283
# Name: 춘천, dtype: float32
# 철원
#  wheat          0.073012
# cocoa          0.057890
# kidneybeans    0.057241
# Name: 철원, dtype: float32
# 속초
#  wheat     0.067120
# grapes    0.058626
# maize     0.058033
# Name: 속초, dtype: float32
# 원주
#  wheat     0.067121
# lentil    0.058627
# maize     0.058034
# Name: 원주, dtype: float32
# 대관령
#  wheat    0.072875
# maize    0.070929
# rice     0.064342
# Name: 대관령, dtype: float32
# 태백
#  wheat    0.074154
# maize    0.063932
# cocoa    0.058281
# Name: 태백, dtype: float32
# 인제
#  wheat     0.074049
# grapes    0.057503
# lentil    0.057503
# Name: 인제, dtype: float32
# 홍천
#  wheat     0.074283
# maize     0.064440
# lentil    0.058080
# Name: 홍천, dtype: float32
# 대전
#  wheat     0.066430
# maize     0.064587
# lentil    0.058283
# Name: 대전, dtype: float32
# 금산
#  wheat     0.074059
# maize     0.064206
# lentil    0.057856
# Name: 금산, dtype: float32
# 부여
#  wheat     0.067121
# lentil    0.058627
# maize     0.058034
# Name: 부여, dtype: float32
# 천안
#  wheat     0.067121
# lentil    0.058627
# maize     0.058034
# Name: 천안, dtype: float32
# 보령
#  wheat     0.066392
# grapes    0.057906
# lentil    0.057906
# Name: 보령, dtype: float32
# 서산
#  wheat          0.065380
# cocoa          0.058324
# kidneybeans    0.057666
# Name: 서산, dtype: float32
# 청주
#  wheat     0.066430
# maize     0.064587
# lentil    0.058283
# Name: 청주, dtype: float32
# 추풍령
#  wheat     0.067100
# lentil    0.058606
# maize     0.058412
# Name: 추풍령, dtype: float32
# 보은
#  wheat     0.074771
# lentil    0.058221
# maize     0.057290
# Name: 보은, dtype: float32
# 제천
#  wheat     0.074048
# grapes    0.057502
# lentil    0.057502
# Name: 제천, dtype: float32
# 인천
#  wheat     0.066394
# grapes    0.057908
# lentil    0.057908
# Name: 인천, dtype: float32
# 강화
#  wheat     0.074042
# grapes    0.057500
# lentil    0.057500
# Name: 강화, dtype: float32
# 수원
#  wheat          0.065607
# kidneybeans    0.057893
# grapes         0.057516
# Name: 수원, dtype: float32
# 이천
#  wheat     0.066429
# maize     0.064585
# lentil    0.058282
# Name: 이천, dtype: float32
# 양평
#  wheat     0.067100
# lentil    0.058606
# maize     0.058412
# Name: 양평, dtype: float32
# 광주
#  wheat      0.066393
# maize      0.064152
# coconut    0.057890
# Name: 광주, dtype: float32
# 장흥
#  wheat          0.067120
# kidneybeans    0.058645
# maize          0.058033
# Name: 장흥, dtype: float32
# 목포
#  coconut        0.065528
# wheat          0.065286
# kidneybeans    0.057208
# Name: 목포, dtype: float32
# 해남
#  wheat          0.067122
# kidneybeans    0.058647
# maize          0.058034
# Name: 해남, dtype: float32
# 고흥
#  wheat          0.067120
# kidneybeans    0.058645
# maize          0.058033
# Name: 고흥, dtype: float32
# 완도
#  wheat      0.065633
# rice       0.057731
# coconut    0.057320
# Name: 완도, dtype: float32
# 여수
#  coconut    0.067025
# rice       0.058761
# wheat      0.058370
# Name: 여수, dtype: float32
# 전주
#  wheat    0.067222
# maize    0.064981
# cocoa    0.055075
# Name: 전주, dtype: float32
# 임실
#  wheat    0.075563
# maize    0.057685
# cocoa    0.055011
# Name: 임실, dtype: float32
# 군산
#  wheat          0.065831
# kidneybeans    0.058117
# grapes         0.057740
# Name: 군산, dtype: float32
# 부안
#  wheat          0.066327
# kidneybeans    0.058251
# lentil         0.058232
# Name: 부안, dtype: float32
# 정읍
#  wheat    0.067222
# maize    0.064981
# cocoa    0.055075
# Name: 정읍, dtype: float32
# 남원
#  wheat    0.074852
# maize    0.064601
# cocoa    0.054639
# Name: 남원, dtype: float32
# 장수
#  wheat    0.074164
# maize    0.063938
# cocoa    0.058286
# Name: 장수, dtype: float32
# 부산
#  rice       0.058541
# wheat      0.058151
# coconut    0.058132
# Name: 부산, dtype: float32
# 밀양
#  wheat    0.067604
# maize    0.058108
# cocoa    0.055459
# Name: 밀양, dtype: float32
# 창원
#  wheat      0.065420
# coconut    0.064899
# banana     0.064855
# Name: 창원, dtype: float32
# 통영
#  wheat      0.065802
# coconut    0.065785
# rice       0.057899
# Name: 통영, dtype: float32
# 거제
#  wheat          0.066943
# rice           0.058631
# kidneybeans    0.058468
# Name: 거제, dtype: float32
# 진주
#  wheat    0.075564
# maize    0.057672
# cocoa    0.055012
# Name: 진주, dtype: float32
# 산청
#  wheat    0.067380
# cocoa    0.059514
# maize    0.057883
# Name: 산청, dtype: float32
# 남해
#  wheat          0.067119
# kidneybeans    0.058644
# maize          0.058033
# Name: 남해, dtype: float32
# 거창
#  wheat    0.074852
# maize    0.064601
# cocoa    0.054639
# Name: 거창, dtype: float32
# 합천
#  wheat    0.067603
# maize    0.058107
# cocoa    0.055458
# Name: 합천, dtype: float32
# 울산
#  wheat    0.067225
# maize    0.064984
# cocoa    0.055077
# Name: 울산, dtype: float32
# 제주
#  banana         0.065781
# wheat          0.058194
# kidneybeans    0.058122
# Name: 제주, dtype: float32
# 고산
#  coconut        0.059031
# kidneybeans    0.058960
# wheat          0.058618
# Name: 고산, dtype: float32
# 서귀포
#  rice       0.067204
# coconut    0.058785
# wheat      0.058636
# Name: 서귀포, dtype: float32
# 대구
#  wheat     0.066813
# lentil    0.058666
# maize     0.057715
# Name: 대구, dtype: float32
# 구미
#  wheat     0.066811
# lentil    0.058664
# maize     0.057712
# Name: 구미, dtype: float32
# 문경
#  wheat     0.066408
# maize     0.064962
# lentil    0.058262
# Name: 문경, dtype: float32
# 영주
#  wheat    0.067201
# maize    0.065358
# cocoa    0.055045
# Name: 영주, dtype: float32
# 봉화
#  wheat     0.073822
# cocoa     0.058309
# grapes    0.057276
# Name: 봉화, dtype: float32
# 안동
#  wheat     0.066429
# maize     0.064586
# lentil    0.058283
# Name: 안동, dtype: float32
# 영덕
#  wheat     0.066564
# cocoa     0.059087
# lentil    0.058418
# Name: 영덕, dtype: float32
# 울진
#  wheat    0.067221
# maize    0.064980
# cocoa    0.055074
# Name: 울진, dtype: float32
# 의성
#  wheat     0.074590
# lentil    0.058244
# maize     0.057306
# Name: 의성, dtype: float32
# 영천
#  wheat     0.066789
# lentil    0.058643
# maize     0.058099
# Name: 영천, dtype: float32
# 포항
#  wheat      0.067149
# coconut    0.059023
# maize      0.058036
# Name: 포항, dtype: float32
# 울릉도
#  wheat          0.066839
# cocoa          0.059022
# kidneybeans    0.058781
# Name: 울릉도, dtype: float32
# 동해
#  wheat    0.067913
# maize    0.058429
# cocoa    0.055419
# Name: 동해, dtype: float32
# 영월
#  wheat     0.074283
# maize     0.064440
# lentil    0.058080
# Name: 영월, dtype: float32
# 흑산도
#  coconut    0.059308
# wheat      0.058599
# lentil     0.058513
# Name: 흑산도, dtype: float32
# 동두천
#  wheat     0.066429
# maize     0.064586
# lentil    0.058283
# Name: 동두천, dtype: float32
# 문산
#  wheat          0.065606
# kidneybeans    0.057892
# grapes         0.057515
# Name: 문산, dtype: float32
# 진도
#  wheat     0.067057
# cocoa     0.059346
# grapes    0.058673
# Name: 진도, dtype: float32
# 상주
#  wheat     0.066586
# cocoa     0.059120
# lentil    0.058439
# Name: 상주, dtype: float32
# 고창
#  wheat      0.066290
# coconut    0.057823
# banana     0.057819
# Name: 고창, dtype: float32

# %%
# %time df_xg = predict_6m_all_region(3, 2100)

for col in df_xg.columns:
    df_xg = df_xg.sort_values(by=col, ascending=False)
    print(col, '\n', df_xg[col].head(3))
# Out:
# CPU times: user 1min 6s, sys: 556 ms, total: 1min 6s
# Wall time: 1min 13s
# 서울
#  wheat      0.066671
# coconut    0.058220
# banana     0.058210
# Name: 서울, dtype: float32
# 관악산
#  wheat          0.065890
# rice           0.058279
# kidneybeans    0.057813
# Name: 관악산, dtype: float32
# 춘천
#  wheat     0.066810
# lentil    0.058663
# maize     0.057711
# Name: 춘천, dtype: float32
# 철원
#  wheat     0.06640
# grapes    0.05791
# lentil    0.05791
# Name: 철원, dtype: float32
# 속초
#  wheat    0.067379
# cocoa    0.059515
# maize    0.057883
# Name: 속초, dtype: float32
# 원주
#  wheat     0.066593
# lentil    0.058446
# maize     0.057494
# Name: 원주, dtype: float32
# 대관령
#  wheat     0.075296
# grapes    0.058402
# maize     0.057829
# Name: 대관령, dtype: float32
# 태백
#  wheat          0.073527
# cocoa          0.062328
# kidneybeans    0.057393
# Name: 태백, dtype: float32
# 인제
#  wheat     0.074589
# lentil    0.058243
# maize     0.057305
# Name: 인제, dtype: float32
# 홍천
#  wheat     0.074350
# lentil    0.058004
# maize     0.057460
# Name: 홍천, dtype: float32
# 대전
#  wheat      0.067166
# coconut    0.059057
# maize      0.057670
# Name: 대전, dtype: float32
# 금산
#  wheat    0.075360
# maize    0.058073
# cocoa    0.054806
# Name: 금산, dtype: float32
# 부여
#  wheat    0.067386
# maize    0.057890
# cocoa    0.055241
# Name: 부여, dtype: float32
# 천안
#  wheat     0.066585
# cocoa     0.059119
# lentil    0.058439
# Name: 천안, dtype: float32
# 보령
#  wheat          0.065605
# kidneybeans    0.057891
# grapes         0.057514
# Name: 보령, dtype: float32
# 서산
#  wheat          0.065605
# kidneybeans    0.057891
# grapes         0.057514
# Name: 서산, dtype: float32
# 청주
#  wheat      0.066156
# coconut    0.058444
# lentil     0.058009
# Name: 청주, dtype: float32
# 추풍령
#  wheat    0.067358
# cocoa    0.059483
# maize    0.058260
# Name: 추풍령, dtype: float32
# 보은
#  wheat     0.074343
# cocoa     0.058457
# lentil    0.057998
# Name: 보은, dtype: float32
# 제천
#  wheat    0.075097
# maize    0.064462
# rice     0.050669
# Name: 제천, dtype: float32
# 인천
#  wheat      0.064775
# coconut    0.057069
# banana     0.057065
# Name: 인천, dtype: float32
# 강화
#  wheat          0.073256
# kidneybeans    0.057485
# grapes         0.057109
# Name: 강화, dtype: float32
# 수원
#  wheat     0.067122
# lentil    0.058628
# maize     0.058036
# Name: 수원, dtype: float32
# 이천
#  wheat     0.066593
# lentil    0.058446
# maize     0.057494
# Name: 이천, dtype: float32
# 양평
#  wheat     0.066593
# lentil    0.058446
# maize     0.057494
# Name: 양평, dtype: float32
# 광주
#  wheat      0.066533
# coconut    0.066521
# maize      0.057036
# Name: 광주, dtype: float32
# 장흥
#  wheat    0.067913
# maize    0.058429
# cocoa    0.055418
# Name: 장흥, dtype: float32
# 목포
#  wheat      0.065684
# coconut    0.065134
# banana     0.065119
# Name: 목포, dtype: float32
# 해남
#  wheat          0.067122
# kidneybeans    0.058647
# maize          0.058035
# Name: 해남, dtype: float32
# 고흥
#  wheat          0.067118
# kidneybeans    0.058643
# maize          0.058031
# Name: 고흥, dtype: float32
# 완도
#  wheat      0.065455
# coconut    0.064934
# banana     0.064890
# Name: 완도, dtype: float32
# 여수
#  banana     0.065682
# rice       0.058085
# coconut    0.057725
# Name: 여수, dtype: float32
# 전주
#  wheat      0.066949
# coconut    0.058838
# maize      0.057453
# Name: 전주, dtype: float32
# 임실
#  wheat    0.074852
# maize    0.064601
# cocoa    0.054639
# Name: 임실, dtype: float32
# 군산
#  coconut    0.065299
# wheat      0.065058
# banana     0.057022
# Name: 군산, dtype: float32
# 부안
#  wheat      0.065773
# maize      0.063930
# coconut    0.058061
# Name: 부안, dtype: float32
# 정읍
#  wheat    0.067386
# maize    0.057890
# cocoa    0.055241
# Name: 정읍, dtype: float32
# 남원
#  wheat          0.075166
# maize          0.057470
# pomegranate    0.054710
# Name: 남원, dtype: float32
# 장수
#  wheat    0.075566
# maize    0.057687
# cocoa    0.055014
# Name: 장수, dtype: float32
# 부산
#  banana         0.065778
# wheat          0.058190
# kidneybeans    0.058118
# Name: 부산, dtype: float32
# 밀양
#  wheat     0.066950
# orange    0.058805
# maize     0.057453
# Name: 밀양, dtype: float32
# 창원
#  wheat      0.066961
# coconut    0.058598
# maize      0.058148
# Name: 창원, dtype: float32
# 통영
#  wheat      0.065426
# coconut    0.065016
# banana     0.064971
# Name: 통영, dtype: float32
# 거제
#  wheat      0.065761
# coconut    0.065675
# banana     0.057369
# Name: 거제, dtype: float32
# 진주
#  wheat          0.075163
# maize          0.057467
# pomegranate    0.054707
# Name: 진주, dtype: float32
# 산청
#  wheat    0.067386
# maize    0.057890
# cocoa    0.055240
# Name: 산청, dtype: float32
# 남해
#  coconut    0.066450
# wheat      0.066132
# rice       0.057852
# Name: 남해, dtype: float32
# 거창
#  wheat    0.075361
# maize    0.058074
# cocoa    0.054807
# Name: 거창, dtype: float32
# 합천
#  wheat     0.066949
# orange    0.058804
# maize     0.057453
# Name: 합천, dtype: float32
# 울산
#  wheat      0.066533
# coconut    0.066521
# maize      0.057036
# Name: 울산, dtype: float32
# 제주
#  papaya    0.061598
# wheat     0.059790
# cocoa     0.055699
# Name: 제주, dtype: float32
# 고산
#  coconut        0.058619
# kidneybeans    0.058551
# banana         0.058279
# Name: 고산, dtype: float32
# 서귀포
#  banana    0.065942
# papaya    0.059523
# rice      0.058387
# Name: 서귀포, dtype: float32
# 대구
#  orange      0.065496
# wheat       0.065327
# chickpea    0.057644
# Name: 대구, dtype: float32
# 구미
#  wheat     0.066595
# lentil    0.058448
# maize     0.057496
# Name: 구미, dtype: float32
# 문경
#  wheat    0.067581
# maize    0.058494
# cocoa    0.055437
# Name: 문경, dtype: float32
# 영주
#  wheat    0.067581
# maize    0.058494
# cocoa    0.055437
# Name: 영주, dtype: float32
# 봉화
#  wheat    0.074869
# maize    0.064235
# cocoa    0.054665
# Name: 봉화, dtype: float32
# 안동
#  wheat     0.066594
# lentil    0.058447
# maize     0.057495
# Name: 안동, dtype: float32
# 영덕
#  wheat     0.066573
# lentil    0.058426
# maize     0.057883
# Name: 영덕, dtype: float32
# 울진
#  wheat    0.067380
# cocoa    0.059514
# maize    0.057884
# Name: 울진, dtype: float32
# 의성
#  wheat          0.074155
# pomegranate    0.058225
# lentil         0.057809
# Name: 의성, dtype: float32
# 영천
#  wheat          0.066356
# pomegranate    0.058626
# lentil         0.058209
# Name: 영천, dtype: float32
# 포항
#  wheat          0.066319
# coconut        0.066095
# pomegranate    0.057763
# Name: 포항, dtype: float32
# 울릉도
#  wheat     0.067277
# cocoa     0.059460
# grapes    0.058786
# Name: 울릉도, dtype: float32
# 동해
#  wheat    0.067224
# maize    0.064983
# cocoa    0.055076
# Name: 동해, dtype: float32
# 영월
#  wheat     0.074351
# lentil    0.058005
# maize     0.057461
# Name: 영월, dtype: float32
# 흑산도
#  coconut        0.058649
# kidneybeans    0.058646
# wheat          0.057941
# Name: 흑산도, dtype: float32
# 동두천
#  wheat     0.066810
# lentil    0.058663
# maize     0.057711
# Name: 동두천, dtype: float32
# 문산
#  wheat     0.067346
# lentil    0.058852
# maize     0.058260
# Name: 문산, dtype: float32
# 진도
#  wheat          0.066326
# kidneybeans    0.058249
# grapes         0.058232
# Name: 진도, dtype: float32
# 상주
#  wheat     0.066595
# lentil    0.058448
# maize     0.057496
# Name: 상주, dtype: float32
# 고창
#  wheat      0.066155
# coconut    0.058428
# lentil     0.058009
# Name: 고창, dtype: float32
